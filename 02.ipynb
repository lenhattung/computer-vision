# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Thư mục chứa hình ảnh
my_dir = 'C:/Users/tungi/OneDrive/Documents/src_cv/img/01'

# %%
# Đọc nhiều ảnh
imgs =  get_image_list(my_dir)

# %%
# Hiển thị toàn bộ ảnh bằng hàm display

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (500, 332)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>
# (500, 332)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>
# (500, 375)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>
# (500, 332)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>
# (500, 332)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x332>
