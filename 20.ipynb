# %%
import cv2
import numpy as np

# %%
def display(title, img):
    cv2.imshow(title, img)
    # Chờ một khoảng thời gian
    cv2.waitKey(0)
    # Đóng window
    cv2.destroyWindow(title)

# %%
# Tạo một ảnh
img =  np.zeros((400, 400, 3), dtype=np.uint8)
display('Image', img)

# %%
# Vẽ đường thẳng
cv2.line(img, (50, 50) , (350, 50), (0,0,255), 2)
display('Image', img)

# %%
# Vẽ hình tròn
cv2.circle(img, (100,100), 50, (0, 255, 0), -1)
display('Image', img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Vẽ đường thẳng
#       2 cv2.circle(img, (100,100), 50, (0, 255, 0), -1)
# ----> 3 display('Image', img)
#
# Cell In[3], line 6, in display(title, img)
#       4 cv2.waitKey(0)
#       5 # Đóng window
# ----> 6 cv2.destroyWindow(title)
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:1261: error: (-27:Null pointer) NULL window: 'Image' in function 'cvDestroyWindow'

# %%
# Vẽ hình chữ nhật
cv2.rectangle(img, (100,100),(300,300), (255, 0, 0), -1)
display('Image', img)

# %%
# Ghi text trên hình ảnh
content = 'Le Nhat Tung'
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, content, (10, 380), font, 0.6, (255, 255, 255), 2)
display('Image', img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[10], line 5
#       3 font = cv2.FONT_HERSHEY_SIMPLEX
#       4 cv2.putText(img, content, (10, 380), font, 0.6, (255, 255, 255), 2)
# ----> 5 display('Image', img)
#
# Cell In[3], line 6, in display(title, img)
#       4 cv2.waitKey(0)
#       5 # Đóng window
# ----> 6 cv2.destroyWindow(title)
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:1261: error: (-27:Null pointer) NULL window: 'Image' in function 'cvDestroyWindow'
